# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as mt
import os

# %%
os.chdir('C:/Users/ADMIN/Desktop/Tanmay')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ADMIN\\Desktop\\Tanmay'

# %%
#  Load CSV in python by skipping second row.
bank_customer_data = pd.read_csv('Bank customer Data.csv',encoding="ISO-8859-1", skiprows=[1])

# %%
bank_customer_data.head(5)
# Out:
#    Customer ID     Name  Surname  Gender  Age            Region  \
# 0    400000002  Jasmine   Miller  Female   34  Northern Ireland
# 1    100000003     Liam    Brown    Male   46           England
# 2    300000004   Trevor     Parr    Male   32             Wales
# 3    100000005  Deirdre  Pullman  Female   38           England
# 4    300000006      Ava  Coleman  Female   30             Wales
#
#   Job Classification Date Joined    Balance
# 0        Blue Collar   06.Jan.15   36919.73
# 1       White Collar   07.Jan.15  101536.83
# 2       White Collar   08.Jan.15    1421.52
# 3        Blue Collar   09.Jan.15   35639.79
# 4        Blue Collar   09.Jan.15  122443.77

# %%
len(bank_customer_data)
# Out:
# 4013

# %%
bank_customer_data.count()
# Out:
# Customer ID           4013
# Name                  4013
# Surname               4013
# Gender                4013
# Age                   4013
# Region                4013
# Job Classification    4013
# Date Joined           4013
# Balance               4013
# dtype: int64

# %%
type(bank_customer_data)
# Out:
# pandas.core.frame.DataFrame

# %%
bank_customer_data.columns
# Out:
# Index(['Customer ID', 'Name', 'Surname', 'Gender', 'Age', 'Region',
#        'Job Classification', 'Date Joined', 'Balance'],
#       dtype='object')

# %%
bank_customer_data.shape
# Out:
# (4013, 9)

# %%
bank_customer_data.dtypes
# Out:
# Customer ID             int64
# Name                   object
# Surname                object
# Gender                 object
# Age                     int64
# Region                 object
# Job Classification     object
# Date Joined            object
# Balance               float64
# dtype: object

# %%
# Extract the unique region and its count and store in data frame with index key. 
unique_region=bank_customer_data['Region'].value_counts()
unique_region
# Out:
# England             2158
# Scotland            1124
# Wales                520
# Northern Ireland     211
# Name: Region, dtype: int64

# %%
unique_region = pd.DataFrame({'unique_region':unique_region.index, 'Count':unique_region.values})

# %%
unique_region.head(5)
# Out:
#    Count     unique_region
# 0   2158           England
# 1   1124          Scotland
# 2    520             Wales
# 3    211  Northern Ireland

# %%
type(unique_region)
# Out:
# pandas.core.frame.DataFrame

# %%
#Sort the region by its name

bank_customer_data1=bank_customer_data.sort_values(['Region','Name','Surname'], ascending = True)

# %%
bank_customer_data1.head(5)
# Out:
#       Customer ID     Name   Surname  Gender  Age   Region Job Classification  \
# 3501    100003503  Abigail   Abraham  Female   48  England       White Collar
# 958     100000960  Abigail     Allan  Female   36  England       White Collar
# 3879    100003881  Abigail  Buckland  Female   36  England       White Collar
# 930     100000932  Abigail  Ferguson  Female   30  England       White Collar
# 3883    100003885  Abigail     Mills  Female   29  England       White Collar
#
#      Date Joined   Balance
# 3501   03.Dec.15  35410.35
# 958    21.Jun.15  31644.37
# 3879   23.Dec.15  47392.56
# 930    20.Jun.15  14184.70
# 3883   23.Dec.15     98.68

# %%
bank_customer_data1.tail(5)
# Out:
#       Customer ID    Name   Surname  Gender  Age Region Job Classification  \
# 2582    300002584  Yvonne    Slater  Female   32  Wales       White Collar
# 551     300000553     Zoe  Ferguson  Female   33  Wales        Blue Collar
# 1182    300001184     Zoe  Hemmings  Female   44  Wales       White Collar
# 2791    300002793     Zoe     Payne  Female   26  Wales       White Collar
# 3464    300003466     Zoe   Randall  Female   44  Wales              Other
#
#      Date Joined   Balance
# 2582   12.Oct.15  51208.53
# 551    18.May.15  53715.28
# 1182   12.Jul.15  29607.52
# 2791   25.Oct.15  58699.25
# 3464   30.Nov.15  44752.01

# %%
# Convert the required data types

# %%
bank_customer_data1['Region'].dtype
# Out:
# dtype('O')

# %%
bank_customer_data1.describe()
# Out:
#         Customer ID          Age        Balance
# count  4.013000e+03  4013.000000    4013.000000
# mean   1.697005e+08    38.615500   39747.997314
# std    8.865796e+07     9.816407   29840.316134
# min    1.000000e+08    15.000000      11.520000
# 25%    1.000020e+08    31.000000   16111.390000
# 50%    1.000038e+08    37.000000   33563.670000
# 75%    2.000031e+08    45.000000   57520.310000
# max    4.000038e+08    64.000000  183467.700000

# %%
#check for null value
pd.isnull(bank_customer_data1).any()
# Out:
# Customer ID           False
# Name                  False
# Surname               False
# Gender                False
# Age                   False
# Region                False
# Job Classification    False
# Date Joined           False
# Balance               False
# dtype: bool

# %%
bank_customer_data1.groupby(['Region','Job Classification','Gender'])['Balance'].describe()
# Out:
#                                             count          mean           std  \
# Region           Job Classification Gender
# England          Blue Collar        Female  163.0  37782.157178  28282.672979
#                                     Male    181.0  39275.391602  32363.492021
#                  Other              Female  171.0  41665.655322  28867.179774
#                                     Male    143.0  39633.689301  30342.390591
#                  White Collar       Female  757.0  40085.413421  30907.577821
#                                     Male    743.0  38109.215020  28965.292522
# Northern Ireland Blue Collar        Female   29.0  39138.120345  31807.450886
#                                     Male     12.0  37545.858333  33458.647153
#                  Other              Female   93.0  39237.491828  31240.334403
#                                     Male     12.0  35284.429167  23944.727785
# ...

# %%
bank_customer_data1.groupby(['Region','Job Classification','Gender'])['Age'].describe()
# Out:
#                                             count       mean       std   min  \
# Region           Job Classification Gender
# England          Blue Collar        Female  163.0  34.644172  6.702387  18.0
#                                     Male    181.0  34.265193  6.544408  18.0
#                  Other              Female  171.0  35.163743  7.030779  18.0
#                                     Male    143.0  34.377622  7.395092  18.0
#                  White Collar       Female  757.0  34.775429  6.784848  18.0
#                                     Male    743.0  34.970390  6.795368  18.0
# Northern Ireland Blue Collar        Female   29.0  29.827586  7.648851  17.0
#                                     Male     12.0  28.916667  4.461111  21.0
#                  Other              Female   93.0  30.698925  8.067359  17.0
#                                     Male     12.0  27.916667  5.930788  17.0
#                  White Collar       Female   35.0  30.828571  8.378845  15.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_bank_grpby_region = bank_customer_data1.groupby(['Region','Gender'])['Balance'].mean()
plt.xlabel('Region')
plt.ylabel('Average Balance region wise  ')
plt.title('Average Balance for each Region gender wise')
df_bank_grpby_region.plot.bar()
plt.show()

# %%
df_bank_grpby_region = bank_customer_data1.groupby(['Job Classification','Gender'])['Balance'].mean()
plt.xlabel('Job Classification')
plt.ylabel('Average Balance of each Job and gender wise')
plt.title('Average Balance for each Job wise')
df_bank_grpby_region.plot.bar()
plt.show()

# %%
df_bank_grpby_region=bank_customer_data1.groupby(['Region','Gender'])['Customer ID'].count()
plt.xlabel('Region')
plt.ylabel('Number of Customer gender wise ')
plt.title('Number of Customer in each Region')
df_bank_grpby_region.plot.bar()
plt.show()

# %%
df_bank_grpby_job_classification = bank_customer_data1.groupby(['Job Classification'])['Customer ID'].count()
plt.xlabel('Job Classification')
plt.ylabel('No of Customers')
df_bank_grpby_job_classification.plot.bar()
plt.show()

# %%
fig4 = plt.figure()
ax = fig4.add_subplot(1,1,1)
ax.set_xlabel('age')
ax.set_ylabel('Balance')
ax.set_title('Age vs Balance')
ax.scatter(bank_customer_data1['Age'],bank_customer_data1['Balance'],color = 'r') #You can also add more variables here to represent color and size.
plt.show();

# %%
bank_customer_data1.hist(column='Balance', rwidth=0.98, color='g',bins=20)
plt.title('Balance distribution')
plt.xlabel('Balance')
plt.ylabel('Number of Customer')
plt.show()

# %%
bank_customer_data1.hist(column='Age',bins = 13,color='r') # Here you can play with number of bins
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Customer')
plt.show()

# %%
#Calculate duration of the customers in the bank#Calcul

# %%
df_bank1 = bank_customer_data1.copy()

# %%
df_bank1.head()
# Out:
#       Customer ID     Name   Surname  Gender  Age   Region Job Classification  \
# 3501    100003503  Abigail   Abraham  Female   48  England       White Collar
# 958     100000960  Abigail     Allan  Female   36  England       White Collar
# 3879    100003881  Abigail  Buckland  Female   36  England       White Collar
# 930     100000932  Abigail  Ferguson  Female   30  England       White Collar
# 3883    100003885  Abigail     Mills  Female   29  England       White Collar
#
#      Date Joined   Balance
# 3501   03.Dec.15  35410.35
# 958    21.Jun.15  31644.37
# 3879   23.Dec.15  47392.56
# 930    20.Jun.15  14184.70
# 3883   23.Dec.15     98.68

# %%
df_bank1['Date Joined'] = pd.to_datetime(df_bank1['Date Joined'])
df_bank1.dtypes
df_bank1.head()
# Out:
#       Customer ID     Name   Surname  Gender  Age   Region Job Classification  \
# 3501    100003503  Abigail   Abraham  Female   48  England       White Collar
# 958     100000960  Abigail     Allan  Female   36  England       White Collar
# 3879    100003881  Abigail  Buckland  Female   36  England       White Collar
# 930     100000932  Abigail  Ferguson  Female   30  England       White Collar
# 3883    100003885  Abigail     Mills  Female   29  England       White Collar
#
#      Date Joined   Balance
# 3501  2015-12-03  35410.35
# 958   2015-06-21  31644.37
# 3879  2015-12-23  47392.56
# 930   2015-06-20  14184.70
# 3883  2015-12-23     98.68

# %%
from datetime import datetime
from datetime import date

# %%
#taken this date as all the customers have joined in 2015 only
date1 = date(2015, 12, 31)

# %%
#df_bank1['days_since'] = datetime.today().date() - df_bank1['Date Joined']
df_bank1['days_since'] = date1 - df_bank1['Date Joined']

# %%
df_bank1.head()
df_bank1.dtypes
# Out:
# Customer ID                     int64
# Name                           object
# Surname                        object
# Gender                         object
# Age                             int64
# Region                         object
# Job Classification             object
# Date Joined            datetime64[ns]
# Balance                       float64
# days_since            timedelta64[ns]
# dtype: object

# %%
df_bank1['days_since_mod'] = (df_bank1['days_since'] / np.timedelta64(1, 'D')).astype(int)
df_bank1.head()
# Out:
#       Customer ID     Name   Surname  Gender  Age   Region Job Classification  \
# 3501    100003503  Abigail   Abraham  Female   48  England       White Collar
# 958     100000960  Abigail     Allan  Female   36  England       White Collar
# 3879    100003881  Abigail  Buckland  Female   36  England       White Collar
# 930     100000932  Abigail  Ferguson  Female   30  England       White Collar
# 3883    100003885  Abigail     Mills  Female   29  England       White Collar
#
#      Date Joined   Balance days_since  days_since_mod
# 3501  2015-12-03  35410.35    28 days              28
# 958   2015-06-21  31644.37   193 days             193
# 3879  2015-12-23  47392.56     8 days               8
# 930   2015-06-20  14184.70   194 days             194
# 3883  2015-12-23     98.68     8 days               8

# %%
#plot the days_since against balance to see the distribution
fig4 = plt.figure()
ax = fig4.add_subplot(1,1,1)
ax.set_xlabel('Days Since')
ax.set_ylabel('Balance')
ax.scatter(df_bank1['days_since_mod'],df_bank1['Balance'],color='g') #You can also add more variables here to represent color and size.
plt.show();
